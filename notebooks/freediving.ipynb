# %% [markdown]
# # Calculation of freediver characteristics and optimal values
# See work_comparison_new12_freediving_only.nb for more details

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import uncertainties as unc
from uncertainties.umath import log
from scipy.optimize import minimize
import trianer

# %matplotlib inline

# %% [markdown]
# ## Functions to calculate missing parameters from experimental data

# %% [markdown]
# ## Function for optimization

# %% [markdown]
# # Dataframe creation

# %%
trianer.divers.get_nery().minimize()#method='L-BFGS-B')
# Out:
# Best ballast weight (Kg) 		=  0.0
# Average optimal ballast weight (Kg) 	=  0.0+/-0
# Best suite thickness (mm) 		=  1.5648397567655394
# Average optimal suite thickness (mm) 	=  1.5+/-0.9
#
# Performance gain = -11.891+/-0.021 %

# %% [markdown]
# ## Values from Stéphane Tourreau

# %%
trianer.divers.get_tourreau().minimize()#method='L-BFGS-B')
# Out:
# Best ballast weight (Kg) 		=  0.2256085243614977
# Average optimal ballast weight (Kg) 	=  0.3+/-0.5
# Best suite thickness (mm) 		=  0.0
# Average optimal suite thickness (mm) 	=  0.0+/-0
#
# Performance gain = -8.3+/-1.1 %

# %%
trianer.divers.get_nery().show()
